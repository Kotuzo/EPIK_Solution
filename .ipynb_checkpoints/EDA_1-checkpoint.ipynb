# %%
DATA_PATH = '/home/kotuzo/DATA_NINJA_COMP/EPIK_Solution/all_data/extracted/transformed/'
SQ_DATA_PATH = '/home/kotuzo/DATA_NINJA_COMP/EPIK_Solution/all_data/extracted/search_queries/'
AD_DATA_PATH = '/home/kotuzo/DATA_NINJA_COMP/EPIK_Solution/all_data/extracted/ads/'

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
pd.set_option('display.max_columns', 50)

# %% [markdown]
# #### LOAD SAMPLE DATASETS

# %%
sq_december = pd.read_csv(SQ_DATA_PATH + 'search_queries_2016_12.csv')

# %%
ads_december = pd.read_csv(AD_DATA_PATH + 'ads_2016_12.csv')
# Out:
# /home/kotuzo/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (34,35,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# #### General look at the data

# %%
sq_december.describe()
# Out:
#         category_id  sessions_count     parent_id
# count  1.569521e+06    1.569265e+06  1.569521e+06
# mean   7.853241e+02    1.226198e+01  4.251702e+02
# std    5.469724e+02    5.086580e+02  4.516621e+02
# min    3.000000e+00    1.000000e+00  0.000000e+00
# 25%    2.020000e+02    1.000000e+00  8.400000e+01
# 50%    7.230000e+02    1.000000e+00  1.010000e+02
# 75%    1.377000e+03    1.000000e+00  6.580000e+02
# max    1.525000e+03    8.930600e+04  1.542000e+03

# %%
ads_december.describe()
# Out:
#                  id       region_id     category_id    subregion_id  \
# count  1.000000e+06  1000000.000000  1000000.000000  1000000.000000
# mean   1.073240e+09        6.597698      581.659224      191.816545
# std    6.198440e+08        4.887037      363.674992      115.602444
# min    4.840000e+02        1.000000        6.000000        1.000000
# 25%    5.362681e+08        2.000000      230.000000       96.000000
# 50%    1.073386e+09        6.000000      575.000000      198.000000
# 75%    1.610476e+09        9.000000      728.000000      287.000000
# max    2.147482e+09       18.000000     1525.000000      507.000000
#
#          district_id       city_id  accurate_location       user_id  \
# count  300503.000000  1.000000e+06     1000000.000000  1.000000e+06
# mean      359.424408  1.143435e+09           0.428120  1.070283e+09
# std       178.575694  6.447710e+08           0.494807  6.206489e+08
# min         1.000000  5.016000e+04           0.000000  1.019000e+04
# 25%       271.000000  5.923137e+08           0.000000  5.318304e+08
# 50%       355.000000  1.086582e+09           0.000000  1.069378e+09
# 75%       391.000000  1.721964e+09           1.000000  1.607883e+09
# max       769.000000  2.147005e+09           1.000000  2.147474e+09
#
#        paidads_id_index  predict_replies   predict_views      reply_call  \
# count     240401.000000   1000000.000000  1000000.000000  1000000.000000
# mean           5.296355         0.182110       20.173057        0.052911
# std           10.249502         0.811711       61.813223        0.340819
# min            3.000000         0.000000        0.000000        0.000000
# 25%            4.000000         0.000000        2.000000        0.000000
# 50%            4.000000         0.000000        6.000000        0.000000
# 75%            4.000000         0.000000       18.000000        0.000000
# max           85.000000        71.000000     9706.000000       44.000000
#
#             reply_sms      reply_chat  reply_call_intent  reply_chat_intent  \
# count  1000000.000000  1000000.000000     1000000.000000     1000000.000000
# mean         0.029326        0.099873           0.405012           0.123912
# std          0.223683        0.537003           1.510796           0.619799
# min          0.000000        0.000000           0.000000           0.000000
# 25%          0.000000        0.000000           0.000000           0.000000
# 50%          0.000000        0.000000           0.000000           0.000000
# 75%          0.000000        0.000000           0.000000           0.000000
# max         22.000000       71.000000         162.000000          83.000000
#
#            parent_id    priceValue
# count  1000000.00000  9.781990e+05
# mean       324.56465  5.141957e+02
# std        383.06405  1.255712e+05
# min          3.00000  1.000000e-02
# 25%         87.00000  2.000000e+01
# 50%         88.00000  4.000000e+01
# 75%        565.00000  1.100000e+02
# max       1542.00000  1.234568e+08

# %%
sq_december.head()
# Out:
#   sorting_date      phrase  category_id  sessions_count  parent_id  name_pl
# 0   2016-11-21         NaN         15.0         85916.0       1307  Wynajem
# 1   2016-11-21   kawalerka         15.0           968.0       1307  Wynajem
# 2   2016-11-21  mieszkanie         15.0           183.0       1307  Wynajem
# 3   2016-11-21    warszawa         15.0           154.0       1307  Wynajem
# 4   2016-11-21    2 pokoje         15.0           150.0       1307  Wynajem

# %%
sq_december['category_id'].nunique()
# Out:
# 387

# %%
sq_december[sq_december['category_id'] == 15].count()
# Out:
# sorting_date      54751
# phrase            54732
# category_id       54751
# sessions_count    54751
# parent_id         54751
# name_pl           54751
# dtype: int64

# %%
ads_december['category_id'].nunique()
# Out:
# 248

# %%
ads_december[ads_december['category_id'] == 15].count()
# Out:
# id                   0
# region_id            0
# category_id          0
# subregion_id         0
# district_id          0
# city_id              0
# accurate_location    0
# user_id              0
# sorting_date         0
# created_at_first     0
# valid_to             0
# title                0
# description          0
# full_description     0
# has_phone            0
# params               0
# private_business     0
# has_person           0
# photo_sizes          0
# paidads_id_index     0
# paidads_valid_to     0
# predict_sold         0
# predict_replies      0
# predict_views        0
# reply_call           0
# reply_sms            0
# reply_chat           0
# reply_call_intent    0
# reply_chat_intent    0
# parent_id            0
# name_pl              0
# priceType            0
# priceValue           0
# state                0
# type                 0
# mark                 0
# size                 0
# dtype: int64

# %%
raw_data = pd.read_csv('/home/kotuzo/DATA_NINJA_COMP/EPIK_Solution/all_data/ads_2016_12_01')

# %%
raw_data.head()
# Out:
#           id  region_id  category_id  subregion_id  district_id     city_id  \
# 0  471113355          3          279           303        385.0  1721963681
# 1  611926916         15          292            21          NaN   959198913
# 2  222597611          4         1505           102        287.0   239224901
# 3  660662971          2          575           287        381.0  2056888083
# 4  144496390          1          279           190          NaN  1640171958
#
#    accurate_location     user_id         sorting_date     created_at_first  \
# 0                  0  2052953831  2016-11-28 09:11:10  2012-07-04 09:18:13
# 1                  0  1491762096  2016-11-29 07:50:45  2012-07-04 20:39:19
# 2                  0   530730361  2016-11-25 13:22:18  2012-07-07 07:22:04
# 3                  0  1581613515  2016-11-23 21:43:16  2012-06-26 22:02:18
# 4                  0  1447566944  2016-11-26 13:55:17  2012-07-06 11:30:25
#
#               valid_to                                              title  \
# 0  2016-12-28 09:11:10  Ekogroszek workowany Pieklorz <CITY> - POLMARK...
# 1  2016-12-29 07:50:45  Poliwęglan komorowy kanalikowy z dostawą na te...
# 2  2016-12-25 13:22:18  DJ na wesele <CITY> DJ Weselny <CITY> PROMOCYJ...
# 3  2016-12-23 21:50:18                               Obrazy jak oryginały
# 4  2016-12-26 14:36:59  KOMINEK MARKOWY, efekt żarzenia, "<SURNAME> <N...
#
#                                          description  \
# 0  Ekogroszek Pieklorz chwałowicki - "Iskierka zi...
# 1  Witamy na stronie firmy K&M Technic\n\nJesteśm...
# 2  Skorzystaj z cen promocyjnych od Stycznia do M...
# 3  Obrazy w porządnych ramach ( robione na zamówi...
# 4  KOMINEK FIRMY ZEPTER "<SURNAME> <NAME> Serce" ...
#
#                                     full_description has_phone  \
# 0  Ekogroszek Pieklorz chwałowicki - "Iskierka zi...         t
# 1  Witamy na stronie firmy K&M Technic\n\nJesteśm...         t
# 2  Skorzystaj z cen promocyjnych od Stycznia do M...         t
# 3  Obrazy w porządnych ramach ( robione na zamówi...         t
# 4  KOMINEK FIRMY ZEPTER "<SURNAME> <NAME> Serce" ...         t
#
#                                            params private_business has_person  \
# 0     price<=>price<br>price<=>940<br>state<=>new         business          t
# 1      price<=>price<br>price<=>19<br>state<=>new         business          t
# 2                                             NaN          private          t
# 3    price<=>price<br>price<=>130<br>state<=>used          private          t
# 4  price<=>arranged<br>price<=>950<br>state<=>new          private          t
#
#                                          photo_sizes  paidads_id_index  \
# 0                            {"1":{"w":489,"h":700}}               NaN
# 1  {"2":{"w":1000,"h":563},"1":{"w":933,"h":700},...               4.0
# 2  {"6":{"w":640,"h":426},"1":{"w":1000,"h":666},...               NaN
# 3      {"2":{"w":346,"h":461},"1":{"w":616,"h":461}}               NaN
# 4  {"1":{"w":616,"h":461},"2":{"w":616,"h":461},"...               NaN
#
#       paidads_valid_to predict_sold  predict_replies  predict_views  \
# 0                  NaN            f                0             19
# 1  2016-12-18 06:40:42            f                2            112
# 2                  NaN            f                1              9
# 3                  NaN            f                0              1
# 4                  NaN            f                0             13
#
#    reply_call  reply_sms  reply_chat  reply_call_intent  reply_chat_intent
# 0           0          0           0                  0                  0
# 1           2          0           0                  9                  0
# 2           0          0           1                  2                  1
# 3           0          0           0                  0                  0
# 4           0          0           0                  0                  0

# %%
raw_data['desc_length'] = raw_data['full_description'].apply(len)

# %%
raw_data.head()
# Out:
#           id  region_id  category_id  subregion_id  district_id     city_id  \
# 0  471113355          3          279           303        385.0  1721963681
# 1  611926916         15          292            21          NaN   959198913
# 2  222597611          4         1505           102        287.0   239224901
# 3  660662971          2          575           287        381.0  2056888083
# 4  144496390          1          279           190          NaN  1640171958
#
#    accurate_location     user_id         sorting_date     created_at_first  \
# 0                  0  2052953831  2016-11-28 09:11:10  2012-07-04 09:18:13
# 1                  0  1491762096  2016-11-29 07:50:45  2012-07-04 20:39:19
# 2                  0   530730361  2016-11-25 13:22:18  2012-07-07 07:22:04
# 3                  0  1581613515  2016-11-23 21:43:16  2012-06-26 22:02:18
# 4                  0  1447566944  2016-11-26 13:55:17  2012-07-06 11:30:25
#
#               valid_to                                              title  \
# 0  2016-12-28 09:11:10  Ekogroszek workowany Pieklorz <CITY> - POLMARK...
# 1  2016-12-29 07:50:45  Poliwęglan komorowy kanalikowy z dostawą na te...
# 2  2016-12-25 13:22:18  DJ na wesele <CITY> DJ Weselny <CITY> PROMOCYJ...
# 3  2016-12-23 21:50:18                               Obrazy jak oryginały
# 4  2016-12-26 14:36:59  KOMINEK MARKOWY, efekt żarzenia, "<SURNAME> <N...
#
#                                          description  \
# 0  Ekogroszek Pieklorz chwałowicki - "Iskierka zi...
# 1  Witamy na stronie firmy K&M Technic\n\nJesteśm...
# 2  Skorzystaj z cen promocyjnych od Stycznia do M...
# 3  Obrazy w porządnych ramach ( robione na zamówi...
# 4  KOMINEK FIRMY ZEPTER "<SURNAME> <NAME> Serce" ...
#
#                                     full_description has_phone  \
# 0  Ekogroszek Pieklorz chwałowicki - "Iskierka zi...         t
# 1  Witamy na stronie firmy K&M Technic\n\nJesteśm...         t
# 2  Skorzystaj z cen promocyjnych od Stycznia do M...         t
# 3  Obrazy w porządnych ramach ( robione na zamówi...         t
# 4  KOMINEK FIRMY ZEPTER "<SURNAME> <NAME> Serce" ...         t
#
#                                            params private_business has_person  \
# 0     price<=>price<br>price<=>940<br>state<=>new         business          t
# 1      price<=>price<br>price<=>19<br>state<=>new         business          t
# 2                                             NaN          private          t
# 3    price<=>price<br>price<=>130<br>state<=>used          private          t
# 4  price<=>arranged<br>price<=>950<br>state<=>new          private          t
#
#                                          photo_sizes  paidads_id_index  \
# 0                            {"1":{"w":489,"h":700}}               NaN
# 1  {"2":{"w":1000,"h":563},"1":{"w":933,"h":700},...               4.0
# 2  {"6":{"w":640,"h":426},"1":{"w":1000,"h":666},...               NaN
# 3      {"2":{"w":346,"h":461},"1":{"w":616,"h":461}}               NaN
# 4  {"1":{"w":616,"h":461},"2":{"w":616,"h":461},"...               NaN
#
#       paidads_valid_to predict_sold  predict_replies  predict_views  \
# 0                  NaN            f                0             19
# 1  2016-12-18 06:40:42            f                2            112
# 2                  NaN            f                1              9
# 3                  NaN            f                0              1
# 4                  NaN            f                0             13
#
#    reply_call  reply_sms  reply_chat  reply_call_intent  reply_chat_intent  \
# 0           0          0           0                  0                  0
# 1           2          0           0                  9                  0
# 2           0          0           1                  2                  1
# 3           0          0           0                  0                  0
# 4           0          0           0                  0                  0
#
#    desc_length
# 0         1819
# 1         1182
# 2         1674
# 3          226
# 4          948

# %%
raw_data['desc_length'].plot.hist(bins=150)

# %%
raw_data.hist(column='desc_length', by='predict_sold', bins=100, figsize=(12,4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f7930468c18>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f792fe8aeb8>], dtype=object)

# %%
def is_new_param(serie):
    if 'new' in str(serie):
        return 1
    else:
        return 0

# %%
raw_data['new'] = raw_data['params'].apply(lambda x: is_new_param(x))

# %%
raw_data[raw_data['category_id'] == 188].hist(column='new', by='predict_sold', bins=2, figsize=(12,4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f78eef4d0f0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f78eeefc0f0>], dtype=object)

# %%
raw_data[raw_data['predict_sold'] == 't']['category_id'].value_counts().index.values[:10]
# Out:
# array([230, 642, 231,  93, 224, 282, 575, 734, 235, 506])

# %%
for x in raw_data[raw_data['predict_sold'] == 't']['category_id'].value_counts().index.values[:10]:
    print(
        raw_data[raw_data['category_id'] == x].hist(column='new', by='predict_sold', figsize=(12,4)))
# Out:
# [<matplotlib.axes._subplots.AxesSubplot object at 0x7f792e73fcc0>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x7f792e65e7f0>]
# [<matplotlib.axes._subplots.AxesSubplot object at 0x7f792e6ba630>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x7f78f04d0358>]
# [<matplotlib.axes._subplots.AxesSubplot object at 0x7f78f04339e8>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x7f78f03a0c88>]
# [<matplotlib.axes._subplots.AxesSubplot object at 0x7f78f03b17f0>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x7f78f0203898>]
# [<matplotlib.axes._subplots.AxesSubplot object at 0x7f78f042bdd8>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x7f792e71de48>]
# [<matplotlib.axes._subplots.AxesSubplot object at 0x7f78f02b4c88>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x7f78f01b6940>]
# [<matplotlib.axes._subplots.AxesSubplot object at 0x7f792e824908>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x7f78f0039e48>]
# [<matplotlib.axes._subplots.AxesSubplot object at 0x7f78eff78400>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x7f78efe85438>]
# [<matplotlib.axes._subplots.AxesSubplot object at 0x7f78efe457f0>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x7f78efcc1470>]
# [<matplotlib.axes._subplots.AxesSubplot object at 0x7f78efcb5198>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x7f78efba49b0>]

# %% [markdown]
# Eventually sth interesting!!!

# %%
def get_percentage_of_sold(ad_df, category_id):
    all_ads = len(ad_df[ad_df['category_id'] == category_id]['predict_sold'])
    sold_ads = len(ad_df[(ad_df['category_id'] == category_id) & (ad_df['predict_sold'] == 't')]['predict_sold'])
    return sold_ads / all_ads

# %%
get_percentage_of_sold(raw_data, 111)
# Out:
# 0.5

# %%
for i in range(1, 2000):
    try:
        print(i, get_percentage_of_sold(raw_data, i))
    except ValueError:
        pass
    except ZeroDivisionError:
        pass
# Out:
# 6 0.014778325123152709
# 14 0.0
# 16 0.0
# 24 0.0
# 53 0.0
# 65 0.18181818181818182
# 80 0.0
# 93 0.11525383984054402
# 100 0.05940066119227898
# 111 0.5
# 140 0.1118421052631579
# 163 0.0
# 168 0.0
# 175 0.08011444921316166
# 179 0.0
# 180 0.14925373134328357
# 182 0.0
# 188 0.25
# 189 0.0
# 190 0.0
# 194 0.0
# 196 0.0
# 199 0.0
# 200 0.0
# 203 0.0
# 207 0.0
# 219 0.045735749005744585
# 224 0.03550474547023296
# 230 0.04421557311551096
# 231 0.09270842641408275
# 235 0.06851169844020798
\
# 0  Ekogroszek Pieklorz chwałowicki - "Iskierka zi...
# 1  Witamy na stronie firmy K&M Technic\n\nJesteśm...
# 2  Skorzystaj z cen promocyjnych od Stycznia do M...
# 3  Obrazy w porządnych ramach ( robione na zamówi...
# 4  KOMINEK FIRMY ZEPTER "<SURNAME> <NAME> Serce" ...
#
#                                     full_description has_phone  \
# 0  Ekogroszek Pieklorz chwałowicki - "Iskierka zi...         t
# 1  Witamy na stronie firmy K&M Technic\n\nJesteśm...         t
# 2  Skorzystaj z cen promocyjnych od Stycznia do M...         t
# 3  Obrazy w porządnych ramach ( robione na zamówi...         t
# 4  KOMINEK FIRMY ZEPTER "<SURNAME> <NAME> Serce" ...         t
#
#                                            params private_business has_person  \
# 0     price<=>price<br>price<=>940<br>state<=>new         business          t
# 1      price<=>price<br>price<=>19<br>state<=>new         business          t
# 2                                             NaN          private          t
# 3    price<=>price<br>price<=>130<br>state<=>used          private          t
# 4  price<=>arranged<br>price<=>950<br>state<=>new          private          t
#
#                                          photo_sizes  paidads_id_index  \
# 0                            {"1":{"w":489,"h":700}}               NaN
# 1  {"2":{"w":1000,"h":563},"1":{"w":933,"h":700},...               4.0
# 2  {"6":{"w":640,"h":426},"1":{"w":1000,"h":666},...               NaN
# 3      {"2":{"w":346,"h":461},"1":{"w":616,"h":461}}               NaN
# 4  {"1":{"w":616,"h":461},"2":{"w":616,"h":461},"...               NaN
#
#       paidads_valid_to predict_sold  predict_replies  predict_views  \
# 0                  NaN            f                0             19
# 1  2016-12-18 06:40:42            f                2            112
# 2                  NaN            f                1              9
# 3                  NaN            f                0              1
# 4                  NaN            f                0             13
#
#    reply_call  reply_sms  reply_chat  reply_call_intent  reply_chat_intent  \
# 0           0          0           0                  0                  0
# 1           2          0           0                  9                  0
# 2           0          0           1                  2                  1
# 3           0          0           0                  0                  0
# 4           0          0           0                  0                  0
#
#    desc_length  new
# 0         1819    1
# 1         1182    1
# 2         1674    0
# 3          226    0
# 4          948    1

# %%
sq_december[sq_december['category_id'] == 15].count()
# Out:
# sorting_date      54751
# phrase            54732
# category_id       54751
# sessions_count    54751
# parent_id         54751
# name_pl           54751
# dtype: int64

# %%
raw_data[(raw_data['predict_sold'] == 'f') & (raw_data['paidads_id_index'] > 0)]['full_description'].count()
# Out:
# 227723

# %%
sq_december.head()
# Out:
#   sorting_date      phrase  category_id  sessions_count  parent_id  name_pl
# 0   2016-11-21         NaN         15.0         85916.0       1307  Wynajem
# 1   2016-11-21   kawalerka         15.0           968.0       1307  Wynajem
# 2   2016-11-21  mieszkanie         15.0           183.0       1307  Wynajem
# 3   2016-11-21    warszawa         15.0           154.0       1307  Wynajem
# 4   2016-11-21    2 pokoje         15.0           150.0       1307  Wynajem

# %%
raw_data[raw_data['predict_sold'] == 't'].groupby('region_id').count()['id'] / raw_data[raw_data['predict_sold'] == 'f'].groupby('region_id').count()['id']
# Out:
# region_id
# 1     0.056873
# 2     0.055487
# 3     0.057723
# 4     0.053745
# 5     0.061225
# 6     0.063163
# 7     0.057002
# 8     0.055773
# 9     0.055177
# 11    0.058152
# 12    0.051648
# 13    0.053657
# 14    0.059675
# 15    0.063243
# 17    0.055183
# 18    0.050393
# Name: id, dtype: float64
